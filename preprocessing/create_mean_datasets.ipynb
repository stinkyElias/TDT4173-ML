# %%
# %load_ext autoreload

# %%
import sys
import os

sys.path.append('../')

from utilities import create_data as create

home_dir = os.path.join(os.path.expanduser('~'), 'Documents/TDT4173-ML')
saved_data_path = os.path.join(home_dir, 'data_processed')

# %%
data = create.CreateTrainingData()

train = data.create_training_data(use_mean_values=True)
test = create.create_test_data(use_mean_values=True)
target = create.create_target_data()
# Out:
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# date_forecast
# 2022-10-21 02:00:00                       NaN                  NaN
# 2022-10-21 03:00:00                       NaN                  NaN
# 2022-10-21 04:00:00                       NaN                  NaN
# 2022-10-21 05:00:00                       NaN                  NaN
# 2022-10-21 06:00:00                       NaN                  NaN
# ...                                       ...                  ...
# 2022-10-28 17:00:00                       NaN                  NaN
# 2022-10-28 18:00:00                       NaN                  NaN
# 2022-10-28 19:00:00                       NaN                  NaN
# 2022-10-28 20:00:00                       NaN                  NaN
# 2022-10-28 21:00:00                       NaN                  NaN
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# date_forecast
# 2022-10-21 02:00:00                   NaN                    NaN
# 2022-10-21 03:00:00                   NaN                    NaN
# 2022-10-21 04:00:00                   NaN                    NaN
# 2022-10-21 05:00:00                   NaN                    NaN
# 2022-10-21 06:00:00                   NaN                    NaN
# ...                                   ...                    ...
# 2022-10-28 17:00:00                   NaN                    NaN
# 2022-10-28 18:00:00                   NaN                    NaN
# 2022-10-28 19:00:00                   NaN                    NaN
# 2022-10-28 20:00:00                   NaN                    NaN
# 2022-10-28 21:00:00                   NaN                    NaN
#
#                      clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  \
# date_forecast
# 2022-10-21 02:00:00              NaN               NaN              NaN
# 2022-10-21 03:00:00              NaN               NaN              NaN
# 2022-10-21 04:00:00              NaN               NaN              NaN
# 2022-10-21 05:00:00              NaN               NaN              NaN
# 2022-10-21 06:00:00              NaN               NaN              NaN
# ...                              ...               ...              ...
# 2022-10-28 17:00:00              NaN               NaN              NaN
# 2022-10-28 18:00:00              NaN               NaN              NaN
# 2022-10-28 19:00:00              NaN               NaN              NaN
# 2022-10-28 20:00:00              NaN               NaN              NaN
# 2022-10-28 21:00:00              NaN               NaN              NaN
#
#                      dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  ...  \
# date_forecast                                                         ...
# 2022-10-21 02:00:00             NaN            NaN               NaN  ...
# 2022-10-21 03:00:00             NaN            NaN               NaN  ...
# 2022-10-21 04:00:00             NaN            NaN               NaN  ...
# 2022-10-21 05:00:00             NaN            NaN               NaN  ...
# 2022-10-21 06:00:00             NaN            NaN               NaN  ...
# ...                             ...            ...               ...  ...
# 2022-10-28 17:00:00             NaN            NaN               NaN  ...
# 2022-10-28 18:00:00             NaN            NaN               NaN  ...
# 2022-10-28 19:00:00             NaN            NaN               NaN  ...
# 2022-10-28 20:00:00             NaN            NaN               NaN  ...
# 2022-10-28 21:00:00             NaN            NaN               NaN  ...
#
#                      sun_elevation:d  super_cooled_liquid_water:kgm2  \
# date_forecast
# 2022-10-21 02:00:00              NaN                             NaN
# 2022-10-21 03:00:00              NaN                             NaN
# 2022-10-21 04:00:00              NaN                             NaN
# 2022-10-21 05:00:00              NaN                             NaN
# 2022-10-21 06:00:00              NaN                             NaN
# ...                              ...                             ...
# 2022-10-28 17:00:00              NaN                             NaN
# 2022-10-28 18:00:00              NaN                             NaN
# 2022-10-28 19:00:00              NaN                             NaN
# 2022-10-28 20:00:00              NaN                             NaN
# 2022-10-28 21:00:00              NaN                             NaN
#
#                      t_1000hPa:K  total_cloud_cover:p  visibility:m  \
# date_forecast
# 2022-10-21 02:00:00          NaN                  NaN           NaN
# 2022-10-21 03:00:00          NaN                  NaN           NaN
# 2022-10-21 04:00:00          NaN                  NaN           NaN
# 2022-10-21 05:00:00          NaN                  NaN           NaN
# 2022-10-21 06:00:00          NaN                  NaN           NaN
# ...                          ...                  ...           ...
# 2022-10-28 17:00:00          NaN                  NaN           NaN
# 2022-10-28 18:00:00          NaN                  NaN           NaN
# 2022-10-28 19:00:00          NaN                  NaN           NaN
# 2022-10-28 20:00:00          NaN                  NaN           NaN
# 2022-10-28 21:00:00          NaN                  NaN           NaN
#
#                      wind_speed_10m:ms  wind_speed_u_10m:ms  \
# date_forecast
# 2022-10-21 02:00:00                NaN                  NaN
# 2022-10-21 03:00:00                NaN                  NaN
# 2022-10-21 04:00:00                NaN                  NaN
# 2022-10-21 05:00:00                NaN                  NaN
# 2022-10-21 06:00:00                NaN                  NaN
# ...                                ...                  ...
# 2022-10-28 17:00:00                NaN                  NaN
# 2022-10-28 18:00:00                NaN                  NaN
# 2022-10-28 19:00:00                NaN                  NaN
# 2022-10-28 20:00:00                NaN                  NaN
# 2022-10-28 21:00:00                NaN                  NaN
#
#                      wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# date_forecast
# 2022-10-21 02:00:00                  NaN                      NaN
# 2022-10-21 03:00:00                  NaN                      NaN
# 2022-10-21 04:00:00                  NaN                      NaN
# 2022-10-21 05:00:00                  NaN                      NaN
# 2022-10-21 06:00:00                  NaN                      NaN
# ...                                  ...                      ...
# 2022-10-28 17:00:00                  NaN                      NaN
# 2022-10-28 18:00:00                  NaN                      NaN
# 2022-10-28 19:00:00                  NaN                      NaN
# 2022-10-28 20:00:00                  NaN                      NaN
# 2022-10-28 21:00:00                  NaN                      NaN
#
#                      pv_measurement
# date_forecast
# 2022-10-21 02:00:00             NaN
# 2022-10-21 03:00:00             NaN
# 2022-10-21 04:00:00             NaN
# 2022-10-21 05:00:00             NaN
# 2022-10-21 06:00:00             NaN
# ...                             ...
# 2022-10-28 17:00:00             NaN
# 2022-10-28 18:00:00             NaN
# 2022-10-28 19:00:00             NaN
# 2022-10-28 20:00:00             NaN
# 2022-10-28 21:00:00             NaN
#
# [8800 rows x 46 columns]

# %%
test.to_csv(os.path.join(saved_data_path, 'mean_test.csv'), index=True)
train.to_csv(os.path.join(saved_data_path, 'mean_train.csv'), index=True)
