# %%
# %load_ext autoreload

# %%
import sys
sys.path.append('../')

# %%
# %autoreload

import os
import h2o
import pandas as pd

from h2o.automl import H2OAutoML
from utilities import save_model as save

home_dir = os.path.join(os.path.expanduser('~'), 'Documents/TDT4173-ML')
train_data_path = os.path.join(home_dir, 'data_processed')

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.20.1" 2023-08-24; OpenJDK Runtime Environment (build 11.0.20.1+1-post-Ubuntu-0ubuntu122.04); OpenJDK 64-Bit Server VM (build 11.0.20.1+1-post-Ubuntu-0ubuntu122.04, mixed mode, sharing)
#   Starting server from /home/stinky/.local/lib/python3.10/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp42jxf3dd
#   JVM stdout: /tmp/tmp42jxf3dd/h2o_stinky_started_from_python.out
#   JVM stderr: /tmp/tmp42jxf3dd/h2o_stinky_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Europe/Oslo
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.42.0.4
# H2O_cluster_version_age:    1 month and 3 days
# H2O_cluster_name:           H2O_from_python_stinky_rcpbsj
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.889 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------

# %%
train = pd.read_csv(os.path.join(train_data_path, 'imputed_after_2n_mean_train.csv'))
train.set_index('date_forecast', inplace=True)

# %%
X_train = h2o.H2OFrame(train)
y = 'pv_measurement'

X = X_train.columns
X.remove(y)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
autoML = H2OAutoML(max_models=30, seed=11)
autoML.train(x=X, y=y, training_frame=X_train)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_1_20231107_104629
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       10/30
# # GBM base models (used / total)           4/10
# # XGBoost base models (used / total)       6/10
# # DRF base models (used / total)           0/2
# # DeepLearning base models (used / total)  0/7
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 5258.900672139318
# RMSE: 72.51827819342734
# MAE: 30.59784773383261
# RMSLE: NaN
# Mean Residual Deviance: 5258.900672139318
# R^2: 0.9913382730446868
# Null degrees of freedom: 9970
# Residual degrees of freedom: 9960
# Null deviance: 6054068997.941342
# Residual deviance: 52436498.601901144
# AIC: 113748.78244983338
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 53644.19617931878
# RMSE: 231.61216759772958
# MAE: 81.2681567994501
# RMSLE: NaN
# Mean Residual Deviance: 53644.19617931878
# R^2: 0.9087337206179766
# Null degrees of freedom: 92950
# Residual degrees of freedom: 92941
# Null deviance: 54636323363.26905
# Residual deviance: 4986281679.06386
# AIC: 1276053.8512484455
#
# Cross-Validation Metrics Summary:
#                         mean         sd           cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  -----------  -----------  ------------  ------------  ------------  ------------  ------------
# mae                     81.1518      1.39762      82.4541       80.0017       82.7383       80.9015       79.6635
# mean_residual_deviance  53637.6      1614.25      55605.2       52180.2       54821         53683.5       51898.3
# mse                     53637.6      1614.25      55605.2       52180.2       54821         53683.5       51898.3
# null_deviance           1.09273e+10  3.92056e+08  1.09211e+10   1.09515e+10   1.13789e+10   1.03052e+10   1.10796e+10
# r2                      0.908661     0.00384357   0.905394      0.911055      0.909814      0.903977      0.913068
# residual_deviance       9.97149e+08  3.11956e+07  1.0332e+09    9.74047e+08   1.02609e+09   9.89333e+08   9.63077e+08
# rmse                    231.577      3.48407      235.808       228.43        234.139       231.697       227.812
# rmsle                   nan          0            nan           nan           nan           nan           nan
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
best_model = autoML.leader
save.save_model_to_local_disk(best_model, '07E_h2o_mean_imputed_after_2n')
