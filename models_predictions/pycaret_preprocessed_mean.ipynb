# %%
# %load_ext autoreload

# %%
# check installed version (must be >3.0)
import pycaret
pycaret.__version__
# Out:
# '3.1.0'

# %%
# %autoreload 
import sys
sys.path.append('../')

import numpy as np
import pandas as pd

from pycaret.regression import *

# %% [markdown]
# # Import data

# %%
test = pd.read_csv('/home/henrikraa/git_repos/TDT4173-ML/data_preprocessed/X_test_mean.csv')

# %%
test
# Out:
#             date_forecast            date_calc  absolute_humidity_2m:gm3  \
# 0     2023-05-01 00:00:00  2023-04-30 07:00:04                     4.325
# 1     2023-05-01 01:00:00  2023-04-30 07:00:04                     4.275
# 2     2023-05-01 02:00:00  2023-04-30 07:00:04                     4.150
# 3     2023-05-01 03:00:00  2023-04-30 07:00:04                     4.025
# 4     2023-05-01 04:00:00  2023-04-30 07:00:04                     3.900
# ...                   ...                  ...                       ...
# 2155  2023-07-03 19:00:00  2023-07-02 07:00:31                     8.400
# 2156  2023-07-03 20:00:00  2023-07-02 07:00:31                     8.600
# 2157  2023-07-03 21:00:00  2023-07-02 07:00:31                     8.875
# 2158  2023-07-03 22:00:00  2023-07-02 07:00:31                     9.000
# 2159  2023-07-03 23:00:00  2023-07-02 07:00:31                     8.950
#
#       air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# ...

# %% [markdown]
# # Load Model

# %%
model = load_model('/home/henrikraa/git_repos/TDT4173-ML/models_training/01H_pycaret_lgbm_mean_no_feature_eng')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('trained_model', LGBMRegressor(n_jobs=-1, random_state=1))])

# %%
predictions = predict_model(model, data=test)

# %%
predictions.head()
# Out:
#          date_forecast            date_calc  absolute_humidity_2m:gm3  \
# 0  2023-05-01 00:00:00  2023-04-30 07:00:04                     4.325
# 1  2023-05-01 01:00:00  2023-04-30 07:00:04                     4.275
# 2  2023-05-01 02:00:00  2023-04-30 07:00:04                     4.150
# 3  2023-05-01 03:00:00  2023-04-30 07:00:04                     4.025
# 4  2023-05-01 04:00:00  2023-04-30 07:00:04                     3.900
#
#    air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# 0              1.28675            912.700012               0.000000
# 1              1.28600           1482.099976               0.000000
# 2              1.28375           1791.300049               0.000000
# 3              1.28200           2312.875000           10124.424805
# 4              1.28100           2198.299805          141748.593750
#
#    clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  dew_point_2m:K  ...  \
# ...

# %%
predictions_kaggle = predictions['prediction_label']
predictions_kaggle
# Out:
# 0         4.262383
# 1         4.262383
# 2         4.628074
# 3        67.310004
# 4       304.855649
#            ...
# 2155     49.346538
# 2156     14.287362
# 2157      4.636330
# 2158      4.144508
# 2159      4.144508
# Name: prediction_label, Length: 2160, dtype: float64

# %%
predictions_kaggle.to_csv('/home/henrikraa/git_repos/TDT4173-ML/data_results/01H_pycaret_lgbm_mean_no_feature_eng.csv', index=True, header='predictions')

# %%
tuned_model = tune_model(model, search_library='optuna', optimize='MAE')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/henrikraa/git_repos/TDT4173-ML/models_predictions/pycaret_preprocessed_mean.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2231302e32342e3130362e313431222c2275736572223a2268656e72696b726161227d/home/henrikraa/git_repos/TDT4173-ML/models_predictions/pycaret_preprocessed_mean.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tuned_model = tune_model(model, search_library='optuna', optimize='MAE')
#
# File ~/anaconda3/envs/pycaret/lib/python3.9/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962 for name, message in global_names.items():
#     963     if globals_d[name] is None:
# --> 964         raise ValueError(message)
#     965 return func(*args, **kwargs)
#
# ...
